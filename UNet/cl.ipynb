# %%
import os

import pandas as pd

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectKBest
from sklearn.ensemble import RandomForestRegressor

import joblib

# %%
gaze_df = pd.read_csv('COLET/gaze_dataset.csv', sep=',')
pupil_df = pd.read_csv('COLET/pupil_dataset.csv', sep=',')
blinks_df = pd.read_csv('COLET/blinks_dataset.csv', sep=',')
annotation_df = pd.read_csv('COLET/annotation_dataset.csv', sep=',')

# %%
print('Gaze:')
print(gaze_df.columns.to_list())
display(gaze_df.head())

print('Pupil:')
print(pupil_df.columns.to_list())
display(pupil_df.head())

print('Blinks:')
print(blinks_df.columns.to_list())
display(blinks_df.head())

print('Annotation:')
print(annotation_df.columns.to_list())
display(annotation_df.head())
# Out:
# Gaze:
# ['VisualAcuity_logMAR_', 'Gender', 'Age', 'Education', 'task_number', 'gaze_timestamp', 'world_index', 'confidence', 'norm_pos_x', 'norm_pos_y', 'base_data', 'gaze_point_3d_x', 'gaze_point_3d_y', 'gaze_point_3d_z', 'eye_center0_3d_x', 'eye_center0_3d_y', 'eye_center0_3d_z', 'gaze_normal0_x', 'gaze_normal0_y', 'gaze_normal0_z', 'eye_center1_3d_x', 'eye_center1_3d_y', 'eye_center1_3d_z', 'gaze_normal1_x', 'gaze_normal1_y', 'gaze_normal1_z']
#    VisualAcuity_logMAR_ Gender  Age  Education  task_number  gaze_timestamp  \
# 0                 -0.04      F   28         18            1     5410.551715
# 1                 -0.04      F   28         18            1     5410.555834
# 2                 -0.04      F   28         18            1     5410.559774
# 3                 -0.04      F   28         18            1     5410.563583
# 4                 -0.04      F   28         18            1     5410.568291
#
# ...
